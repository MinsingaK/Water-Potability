# %% [markdown]
# Exploration des données

# %%
import pandas as pd
import numpy as np

# %%
water_data = pd.read_csv('water_potability.csv')
water_data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water_data.shape
# Out:
# (3276, 10)

# %%
water_data.replace('Missing', np.nan, inplace = True)
water_data.replace('NA', np.nan, inplace = True)

# %%
water_data.isna()
# Out:
#          ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  \
# 0      True     False   False        False    False         False
# 1     False     False   False        False     True         False
# 2     False     False   False        False     True         False
# 3     False     False   False        False    False         False
# 4     False     False   False        False    False         False
# ...     ...       ...     ...          ...      ...           ...
# 3271  False     False   False        False    False         False
# 3272  False     False   False        False     True         False
# 3273  False     False   False        False     True         False
# 3274  False     False   False        False     True         False
# 3275  False     False   False        False     True         False
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0              False            False      False       False
# ...

# %%
water_data.dropna(axis=0, inplace=True)
water_data.reset_index(drop = True, inplace = True)
water_data.head()
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 4   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       18.436524       100.341674   4.628771           0
# 1       11.558279        31.997993   4.075075           0
# 2        8.399735        54.917862   2.559708           0
# 3       13.789695        84.603556   2.672989           0
# 4       12.363817        62.798309   4.401425           0

# %%
water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
#  9   Potability       2011 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 157.2 KB

# %%
water_data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
print(water_data['ph'].unique().size)
print(water_data['Hardness'].unique().size)
print(water_data['Solids'].unique().size)
print(water_data['Chloramines'].unique().size)
print(water_data['Sulfate'].unique().size)
print(water_data['Conductivity'].unique().size)
print(water_data['Organic_carbon'].unique().size)
print(water_data['Trihalomethanes'].unique().size)
print(water_data['Turbidity'].unique().size)
print(water_data['Potability'].unique().size)
# Out:
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2

# %%
water_data.to_csv('Cleaned_water_data.csv')
